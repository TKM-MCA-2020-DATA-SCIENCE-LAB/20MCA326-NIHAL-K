# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()

# %%
x = iris.data

# %%
y = iris.target

# %%
xtr,xte,ytr,yte = train_test_split(x,y,test_size=0.3,random_state=25)

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtr,ytr)
# Out:
# DecisionTreeClassifier()

# %%
ypred = dt.predict(xte)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Accuracy Score**

# %%
print("Accuracy Score of the algorithm : ",accuracy_score(yte,ypred))
# Out:
# Accuracy Score of the algorithm :  0.9777777777777777

# %%
print("confusion Matrix \n\n ", confusion_matrix(yte,ypred))
# Out:
# confusion Matrix
#
#   [[10  3  3]
#  [ 3  7  5]
#  [ 4  5  5]]

# %%
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(dt,filled=True,class_names=iris.target_names,feature_names=iris.feature_names)
plt.show()
